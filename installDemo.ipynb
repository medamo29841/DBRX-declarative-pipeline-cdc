# %%
# %pip install dbdemos -U
import dbdemos
# dbdemos.install('declarative-pipeline-cdc')
dbdemos.install('declarative-pipeline-cdc', overwrite=True, path='/Users/medamo29841@gmail.com/DBRX-declarative-pipeline-cdc/declarative-pipeline-cdc')
